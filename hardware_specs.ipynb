# %%
metas = {
    'ShiDianNao': {"footprint": 4.86, "power": 320/1000, "ops": 194 * 10**9, 'year': 2015, 'commercial': False, 'type': 'embedded'},
    'Eyeriss': {'footprint': 12.25, "power": 278/1000, "ops": 2663 * 10**9, "year": 2017, 'commercial': False, 'type': 'embedded'},
    'EIE': {'footprint': 0.638024, "power": 9.157/1000, "ops": 102 * 10**9, "year": 2016, 'commercial': False, 'type': 'embedded'},
    
    'AngleEye': {'footprint': 289, "power": 3.5, "ops": 84 * 10**9, "year": 2018, 'commercial': False, 'type': 'embedded'},
    'Throuput-Opt': {'footprint': 289, "power": 3.75, "ops": 118 * 10^9, "year": 2018, 'commercial': False, 'type': 'embedded'},
    'FPGAConvNet': {'footprint': 289, "power": 3.5, "ops": 156 * 10**9, "year": 2016, 'commercial': False, 'type': 'embedded'},
    # 'GoingDeeper': {'footprint': 289, "power": 3.5, "ops": 137 * 10^9, "year": 2016, 'commercial': False, 'type': 'embedded'},

    'NVIDIA Jetson TK1': {'footprint': 314, "power": 10.2 , "ops": 155 * 10**9, "year": 2015, 'commercial': True, 'type': 'embedded'},
    'NVIDIA Jetson TX2': {'footprint': 314, "power": 7.5 , "ops": 102 * 10**9, "year": 2017, 'commercial': True, 'type': 'embedded'},
    'TPU Edge': {'footprint': 36, "power": 1.5 , "ops": 4 * 10**12, "year": 2019, 'commercial': True, 'type': 'embedded'},
    "Intel Movidius Myriad X": {"footprint": 71.28, "power": 2, "ops": 4 * 10**12, "year": 2017, 'commercial': True, 'type': 'embedded'},

    "TPU-V1": {'footprint': 330, 'power': 75, "ops": 92 * 10**12, "year": 2015, 'commercial': True, 'type': 'cloud'},
    "TPU-V2": {'footprint': 625, 'power': 280, "ops": 46 * 10**12, "year": 2017, 'commercial': True, 'type': 'cloud'},
    "TPU-V3": {'footprint': 700, 'power': 450, "ops": 123 * 10**12, "year": 2018, 'commercial': True, 'type': 'cloud'},
    "TPU-V4": {'footprint': 400, 'power': 175, "ops": 138 * 10**12, "year": 2020, 'commercial': True, 'type': 'cloud'},
    
    "Groq": {'footprint': 725, 'power': 300, "ops": 820 * 10**12, "year": 2020, 'commercial': True, 'type': 'cloud'},
    "Ascend 910": {'footprint': 456, 'power': 310 , "ops": 640 * 10**12, "year": 2019, 'commercial': True, 'type': 'cloud'},

    "BrainWave": {'footprint':1849 , 'power': 125 , "ops": 40 * 10**12, "year": 2017, 'commercial': True, 'type': 'cloud'},
    # "IntelDLA": {'footprint': , 'power': 125 , "ops": 40 * 10^12, "year": 2018, 'commercial': True, 'type': 'cloud'},

    # "Hanguang 800": {'footprint': 709, 'power': 280, "ops": 825 * 10^12, "year": 2020, 'commercial': True, 'type': 'cloud'},

    "Graphcore C2": {'footprint': 806 * 2, 'power': 300 , "ops": 250 * 10**12, "year": 2019, 'commercial': True, 'type': 'cloud'},
    "Nvidia V100": {'footprint': 815, 'power': 300, "ops": 250 * 10**12, "year": 2017, 'commercial': True, 'type': 'cloud'},
    "Cerebras WSE2": {'footprint': 46255, 'power': 15000, "ops": 850000 * 2 * 2 * 10**9, "year": 2021, 'commercial': True, 'type': 'cloud'},
    
    "Qualcomm A100": {'footprint': 500, 'power': 1 , "ops": 12.37 * 10**12, "year": 2021, 'commercial': True, 'type': 'cloud'},

}

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker
colors = ["tab:blue", "tab:orange"]
shapes = ["o", "v"]

SMALL_SIZE = 26
MEDIUM_SIZE = 30
BIGGER_SIZE = 35

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

plt.style.use('ggplot')

fig, ax = plt.subplots(1, 1, figsize=(30, 20))
print(ax)
for meta_name, meta_item in metas.items():
    dd = meta_item['ops'] / 10 ** 9 / meta_item['footprint'] / meta_item['power']
#     dd = meta_item['ops'] / 10 ** 9  / meta_item['power']
    s = 'o' if meta_item['type'] == "embedded" else 'v'
    if meta_name in ["AngleEye", "Throuput-Opt", "FPGAConvNet"]:
        s = "*"
    if meta_name in ["BrainWave"]:
        s = "s"
    c = 'tab:blue' if meta_item['commercial'] else 'tab:orange'
#     print(meta_name, dd, meta_item)
    ax.scatter(meta_item['year'], dd, s=2000, label=meta_name, marker=s, color=c)
    ax.annotate(meta_name, (meta_item['year']+0.1, dd*(1.3)), fontsize=30)
ax.set_yscale('log')
ax.set_xlabel("Year", fontsize=BIGGER_SIZE)
ax.set_ylabel("GOps / $mm^2$ / W", fontsize=BIGGER_SIZE)
# ax.set_ylabel("GOps / W", fontsize=BIGGER_SIZE)

# ax.legend()
# ax.set_title('Representative models and their sizes',fontsize=BIGGER_SIZE)
fig.tight_layout()
plt.savefig("overview.pdf")
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
